# %% [markdown]
# # Exploratory Data Analysis of Air Qualtiy in India
# TODO - talk about EDA
# TODO - Talk about dataset (source,what it contains, how useful it is)
#
#
# *   Kaggle
# *   information about air quality
# *   can useful to know more briefly about air quality

# %%
pip install opendatasets --upgrade --quiet

# %%
import opendatasets as od

download_url = 'https://www.kaggle.com/datasets/rohanrao/air-quality-data-in-india?resource=download&select=city_day.csv'

od.download(download_url)
# Out:
# Skipping, found downloaded files in "./air-quality-data-in-india" (use force=True to force download)

# %%
data_filename = './air-quality-data-in-india/city_day.csv'
data_filename2 = './air-quality-data-in-india/city_hour.csv'
data_filename3 = './air-quality-data-in-india/station_day.csv'
data_filename4 = './air-quality-data-in-india/station_hour.csv'
data_filename5 = './air-quality-data-in-india/stations.csv'
data_filename6 = './air-quality-data-in-india/City_data_cleaned.csv'

# %% [markdown]
# ## Data Preparatons and Cleaning
# - Load the file using Pandas
# - Look at some information about the data and columns
# - Fix any missing or incoorect values

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(data_filename)
df2 = pd.read_csv(data_filename2)
df3 = pd.read_csv(data_filename3)
df4 = pd.read_csv(data_filename4)
df5 = pd.read_csv(data_filename5)
df6 = pd.read_csv
# Out:
# <ipython-input-52-2d11fc763bf7>:4: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv(data_filename4)

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['City', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['StationId', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['StationId', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3',
#        'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df5.columns
# Out:
# Index(['StationId', 'StationName', 'City', 'State', 'Status'], dtype='object')

# %%
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df2
# Out:
#                  City             Datetime  PM2.5   PM10    NO    NO2    NOx  \
# 0           Ahmedabad  2015-01-01 01:00:00    NaN    NaN  1.00  40.01  36.37
# 1           Ahmedabad  2015-01-01 02:00:00    NaN    NaN  0.02  27.75  19.73
# 2           Ahmedabad  2015-01-01 03:00:00    NaN    NaN  0.08  19.32  11.08
# 3           Ahmedabad  2015-01-01 04:00:00    NaN    NaN  0.30  16.45   9.20
# 4           Ahmedabad  2015-01-01 05:00:00    NaN    NaN  0.12  14.90   7.85
# ...               ...                  ...    ...    ...   ...    ...    ...
# 707870  Visakhapatnam  2020-06-30 20:00:00   9.50  36.00  2.75  25.57  15.85
# 707871  Visakhapatnam  2020-06-30 21:00:00  17.25  49.25  3.62  33.20  20.62
# 707872  Visakhapatnam  2020-06-30 22:00:00  36.00  71.00  2.20  30.80  18.20
# 707873  Visakhapatnam  2020-06-30 23:00:00  15.75  63.00  1.02  28.90  16.00
# 707874  Visakhapatnam  2020-07-01 00:00:00  15.00  66.00  0.40  26.85  14.05
#
# ...

# %%
df3
# Out:
#        StationId        Date  PM2.5    PM10     NO     NO2     NOx    NH3  \
# 0          AP001  2017-11-24  71.36  115.75   1.75   20.65   12.40  12.19
# 1          AP001  2017-11-25  81.40  124.50   1.44   20.50   12.08  10.72
# 2          AP001  2017-11-26  78.32  129.06   1.26   26.00   14.85  10.28
# 3          AP001  2017-11-27  88.76  135.32   6.60   30.85   21.77  12.91
# 4          AP001  2017-11-28  64.18  104.09   2.56   28.07   17.01  11.42
# ...          ...         ...    ...     ...    ...     ...     ...    ...
# 108030     WB013  2020-06-27   8.65   16.46    NaN     NaN     NaN    NaN
# 108031     WB013  2020-06-28  11.80   18.47    NaN     NaN     NaN    NaN
# 108032     WB013  2020-06-29  18.60   32.26  13.65  200.87  214.20  11.40
# 108033     WB013  2020-06-30  16.07   39.30   7.56   29.13   36.69  29.26
# 108034     WB013  2020-07-01  10.50   36.50   7.78   22.50   30.25  27.23
#
#           CO    SO2      O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
df4
# Out:
#         StationId             Datetime  PM2.5    PM10    NO    NO2    NOx  \
# 0           AP001  2017-11-24 17:00:00  60.50   98.00  2.35  30.80  18.25
# 1           AP001  2017-11-24 18:00:00  65.50  111.25  2.70  24.20  15.07
# 2           AP001  2017-11-24 19:00:00  80.00  132.00  2.10  25.18  15.15
# 3           AP001  2017-11-24 20:00:00  81.50  133.25  1.95  16.25  10.23
# 4           AP001  2017-11-24 21:00:00  75.25  116.00  1.43  17.48  10.43
# ...           ...                  ...    ...     ...   ...    ...    ...
# 2589078     WB013  2020-06-30 20:00:00  15.55   47.80  7.27  35.08  42.38
# 2589079     WB013  2020-06-30 21:00:00  15.23   42.30  6.10  26.78  32.85
# 2589080     WB013  2020-06-30 22:00:00  11.40   40.95  6.58  19.53  26.12
# 2589081     WB013  2020-06-30 23:00:00   9.25   34.33  9.17  21.85  31.00
# 2589082     WB013  2020-07-01 00:00:00  10.50   36.50  7.78  22.50  30.25
#
#            NH3    CO    SO2      O3  Benzene  Toluene  Xylene   AQI  \
# ...

# %%
df5
# Out:
#     StationId                                     StationName  \
# 0       AP001                  Secretariat, Amaravati - APPCB
# 1       AP002  Anand Kala Kshetram, Rajamahendravaram - APPCB
# 2       AP003                      Tirumala, Tirupati - APPCB
# 3       AP004                 PWD Grounds, Vijayawada - APPCB
# 4       AP005          GVM Corporation, Visakhapatnam - APPCB
# ..        ...                                             ...
# 225     WB010                       Jadavpur, Kolkata - WBPCB
# 226     WB011    Rabindra Bharati University, Kolkata - WBPCB
# 227     WB012               Rabindra Sarobar, Kolkata - WBPCB
# 228     WB013                       Victoria, Kolkata - WBPCB
# 229     WB014              Ward-32 Bapupara, Siliguri - WBPCB
#
#                   City           State  Status
# 0            Amaravati  Andhra Pradesh  Active
# 1    Rajamahendravaram  Andhra Pradesh     NaN
# 2             Tirupati  Andhra Pradesh     NaN
# ...

# %%
len(df)
# Out:
# 29531

# %%
len(df2)
# Out:
# 707875

# %%
len(df3)
# Out:
# 108035

# %%
len(df4)
# Out:
# 2589083

# %%
len(df5)
# Out:
# 230

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707875 entries, 0 to 707874
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   City        707875 non-null  object
#  1   Datetime    707875 non-null  object
#  2   PM2.5       562787 non-null  float64
#  3   PM10        411138 non-null  float64
#  4   NO          591243 non-null  float64
#  5   NO2         590753 non-null  float64
#  6   NOx         584651 non-null  float64
#  7   NH3         435333 non-null  float64
#  8   CO          621358 non-null  float64
#  9   SO2         577502 non-null  float64
#  10  O3          578667 non-null  float64
#  11  Benzene     544229 non-null  float64
#  12  Toluene     487268 non-null  float64
#  13  Xylene      252046 non-null  float64
#  14  AQI         578795 non-null  float64
#  15  AQI_Bucket  578795 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 86.4+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108035 entries, 0 to 108034
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   StationId   108035 non-null  object
#  1   Date        108035 non-null  object
#  2   PM2.5       86410 non-null   float64
#  3   PM10        65329 non-null   float64
#  4   NO          90929 non-null   float64
#  5   NO2         91488 non-null   float64
#  6   NOx         92535 non-null   float64
#  7   NH3         59930 non-null   float64
#  8   CO          95037 non-null   float64
#  9   SO2         82831 non-null   float64
#  10  O3          82467 non-null   float64
#  11  Benzene     76580 non-null   float64
#  12  Toluene     69333 non-null   float64
#  13  Xylene      22898 non-null   float64
#  14  AQI         87025 non-null   float64
#  15  AQI_Bucket  87025 non-null   object
# dtypes: float64(13), object(3)
# memory usage: 13.2+ MB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2589083 entries, 0 to 2589082
# Data columns (total 16 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   StationId   object
#  1   Datetime    object
#  2   PM2.5       float64
#  3   PM10        float64
#  4   NO          float64
#  5   NO2         float64
#  6   NOx         float64
#  7   NH3         float64
#  8   CO          float64
#  9   SO2         float64
#  10  O3          float64
#  11  Benzene     float64
#  12  Toluene     float64
#  13  Xylene      float64
#  14  AQI         float64
#  15  AQI_Bucket  object
# dtypes: float64(13), object(3)
# memory usage: 316.1+ MB

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StationId    230 non-null    object
#  1   StationName  230 non-null    object
#  2   City         230 non-null    object
#  3   State        230 non-null    object
#  4   Status       133 non-null    object
# dtypes: object(5)
# memory usage: 9.1+ KB

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %%
df2.describe()
# Out:
#                PM2.5           PM10             NO            NO2  \
# count  562787.000000  411138.000000  591243.000000  590753.000000
# mean       67.622994     119.075804      17.421755      28.885157
# std        74.730496     104.224752      32.095211      29.162194
# min         0.010000       0.010000       0.010000       0.010000
# 25%        26.200000      52.380000       3.840000      10.810000
# 50%        46.420000      91.500000       7.960000      20.320000
# 75%        79.490000     147.520000      16.150000      36.350000
# max       999.990000    1000.000000     499.990000     499.510000
#
#                  NOx            NH3             CO            SO2  \
# count  584651.000000  435333.000000  621358.000000  577502.000000
# mean       32.287565      23.607959       2.183539      14.038307
# std        39.756669      28.831900      10.970514      19.305540
# min         0.000000       0.010000       0.000000       0.010000
# ...

# %%
df3.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  86410.000000  65329.000000  90929.000000  91488.000000  92535.000000
# mean      80.272571    157.968427     23.123424     35.240760     41.195055
# std       76.526403    123.418672     34.491019     29.510827     45.145976
# min        0.020000      0.010000      0.010000      0.010000      0.000000
# 25%       31.880000     70.150000      4.840000     15.090000     13.970000
# 50%       55.950000    122.090000     10.290000     27.210000     26.660000
# 75%       99.920000    208.670000     24.980000     46.930000     50.500000
# max     1000.000000   1000.000000    470.000000    448.050000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  59930.000000  95037.000000  82831.000000  82467.000000  76580.000000
# mean      28.732875      1.605749     12.257634     38.134836      3.358029
# ...

# %%
df4.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  1.941394e+06  1.469831e+06  2.035372e+06  2.060110e+06  2.098275e+06
# mean   8.086481e+01  1.584839e+02  2.278825e+01  3.523689e+01  4.055115e+01
# std    8.947618e+01  1.397883e+02  4.846146e+01  3.497508e+01  5.590894e+01
# min    1.000000e-02  1.000000e-02  1.000000e-02  1.000000e-02  0.000000e+00
# 25%    2.816000e+01  6.400000e+01  3.050000e+00  1.310000e+01  1.135000e+01
# 50%    5.259000e+01  1.162500e+02  7.150000e+00  2.479000e+01  2.286000e+01
# 75%    9.774000e+01  2.040000e+02  1.858000e+01  4.548000e+01  4.570000e+01
# max    1.000000e+03  1.000000e+03  5.000000e+02  4.999900e+02  5.000000e+02
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  1.352465e+06  2.089781e+06  1.846346e+06  1.863110e+06  1.727504e+06
# mean   2.870856e+01  1.502366e+00  1.211602e+01  3.806408e+01  3.305493e+00
# ...

# %%
df5.describe()
# Out:
#        StationId                     StationName   City  State  Status
# count        230                             230    230    230     133
# unique       230                             230    127     21       2
# top        AP001  Secretariat, Amaravati - APPCB  Delhi  Delhi  Active
# freq           1                               1     38     38     131

# %% [markdown]
# #Percentage of missing values per column

# %%
missing_percentage = df.isna().sum().sort_values(ascending= False) / len(df)
missing_percentage
# Out:
# Xylene        0.613220
# PM10          0.377231
# NH3           0.349734
# Toluene       0.272290
# Benzene       0.190410
# AQI           0.158511
# AQI_Bucket    0.158511
# PM2.5         0.155701
# NOx           0.141715
# O3            0.136196
# SO2           0.130507
# NO2           0.121398
# NO            0.121296
# CO            0.069723
# City          0.000000
# Date          0.000000
# dtype: float64

# %%
missing_percentage2 = df2.isna().sum().sort_values(ascending= False) / len(df)
missing_percentage2
# Out:
# Xylene        15.435610
# PM10          10.048322
# NH3            9.229014
# Toluene        7.470353
# Benzene        5.541499
# PM2.5          4.913074
# SO2            4.414784
# O3             4.375334
# AQI            4.371000
# AQI_Bucket     4.371000
# NOx            4.172700
# NO2            3.966070
# NO             3.949477
# CO             2.929701
# City           0.000000
# Datetime       0.000000
# dtype: float64

# %%
missing_percentage3 = df3.isna().sum().sort_values(ascending= False) / len(df)
missing_percentage3
# Out:
# Xylene        2.882970
# NH3           1.628966
# PM10          1.446141
# Toluene       1.310555
# Benzene       1.065152
# O3            0.865802
# SO2           0.853476
# PM2.5         0.732281
# AQI           0.711456
# AQI_Bucket    0.711456
# NO            0.579256
# NO2           0.560326
# NOx           0.524872
# CO            0.440148
# StationId     0.000000
# Date          0.000000
# dtype: float64

# %%
missing_percentage4 = df4.isna().sum().sort_values(ascending= False) / len(df)
missing_percentage4
# Out:
# Xylene        70.268667
# NH3           41.875250
# PM10          37.900918
# Toluene       35.297349
# Benzene       29.175409
# SO2           25.151095
# O3            24.583421
# PM2.5         21.932512
# AQI           19.308185
# AQI_Bucket    19.308185
# NO            18.750161
# NO2           17.912465
# CO            16.907724
# NOx           16.620094
# StationId      0.000000
# Datetime       0.000000
# dtype: float64

# %%
missing_percentage5 = df5.isna().sum().sort_values(ascending= False) / len(df)
missing_percentage5
# Out:
# Status         0.003285
# StationId      0.000000
# StationName    0.000000
# City           0.000000
# State          0.000000
# dtype: float64

# %%
missing_percentage[missing_percentage != 0].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
missing_percentage2[missing_percentage2 != 0].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
missing_percentage3[missing_percentage3 != 0].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
missing_percentage4[missing_percentage4 != 0].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
missing_percentage5[missing_percentage5 != 0].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
missing_data = df.isnull().sum()
percent_missing = (missing_data/len(df))*100
data_frame = pd.concat([missing_data,percent_missing.round(2)],axis=1)
data_frame.columns = ['No of missing values','% of missing values']
data_frame.sort_values('% of missing values',ascending=False).style.background_gradient('Blues')
# Out:
# <style type="text/css">
# #T_231f1_row0_col0, #T_231f1_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_231f1_row1_col0, #T_231f1_row1_col1 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_231f1_row2_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_231f1_row2_col1 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_231f1_row3_col0, #T_231f1_row3_col1 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_231f1_row4_col0, #T_231f1_row4_col1 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_231f1_row5_col0, #T_231f1_row5_col1, #T_231f1_row6_col0, #T_231f1_row6_col1 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_231f1_row7_col0, #T_231f1_row7_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_231f1_row8_col0, #T_231f1_row8_col1 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_231f1_row9_col0, #T_231f1_row9_col1 {
#   background-color: #ccdff1;
# ...

# %% [markdown]
# ##Exploratory Analysis and Visualization
# Columns we'll analyze
# 1. City
# 2. StationId
# 3. PM10
# 4. AQI
# 5. AQI_Bucket

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['City', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['StationId', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO',
#        'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df4.columns
# Out:
# Index(['StationId', 'Datetime', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3',
#        'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df5.columns
# Out:
# Index(['StationId', 'StationName', 'City', 'State', 'Status'], dtype='object')

# %%
df.City
# Out:
# 0            Ahmedabad
# 1            Ahmedabad
# 2            Ahmedabad
# 3            Ahmedabad
# 4            Ahmedabad
#              ...
# 29526    Visakhapatnam
# 29527    Visakhapatnam
# 29528    Visakhapatnam
# 29529    Visakhapatnam
# 29530    Visakhapatnam
# Name: City, Length: 29531, dtype: object

# %%
df2.City
# Out:
# 0             Ahmedabad
# 1             Ahmedabad
# 2             Ahmedabad
# 3             Ahmedabad
# 4             Ahmedabad
#               ...
# 707870    Visakhapatnam
# 707871    Visakhapatnam
# 707872    Visakhapatnam
# 707873    Visakhapatnam
# 707874    Visakhapatnam
# Name: City, Length: 707875, dtype: object

# %%
cities = df.City.unique()
cities
# Out:
# array(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru',
#        'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',
#        'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad',
#        'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai',
#        'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram',
#        'Visakhapatnam'], dtype=object)

# %%
cities2 = df2.City.unique()
cities2
# Out:
# array(['Ahmedabad', 'Aizawl', 'Amaravati', 'Amritsar', 'Bengaluru',
#        'Bhopal', 'Brajrajnagar', 'Chandigarh', 'Chennai', 'Coimbatore',
#        'Delhi', 'Ernakulam', 'Gurugram', 'Guwahati', 'Hyderabad',
#        'Jaipur', 'Jorapokhar', 'Kochi', 'Kolkata', 'Lucknow', 'Mumbai',
#        'Patna', 'Shillong', 'Talcher', 'Thiruvananthapuram',
#        'Visakhapatnam'], dtype=object)

# %%
cities_by_day= df.City.value_counts()
cities_by_day
# Out:
# Ahmedabad             2009
# Delhi                 2009
# Mumbai                2009
# Bengaluru             2009
# Lucknow               2009
# Chennai               2009
# Hyderabad             2006
# Patna                 1858
# Gurugram              1679
# Visakhapatnam         1462
# Amritsar              1221
# Jorapokhar            1169
# Jaipur                1114
# Thiruvananthapuram    1112
# Amaravati              951
# Brajrajnagar           938
# Talcher                925
# Kolkata                814
# Guwahati               502
# Coimbatore             386
# Shillong               310
# Chandigarh             304
# Bhopal                 289
# Ernakulam              162
# Kochi                  162
# Aizawl                 113
# Name: City, dtype: int64

# %%
cities_by_hour = df2.City.value_counts()
cities_by_hour
# Out:
# Ahmedabad             48192
# Delhi                 48192
# Mumbai                48192
# Bengaluru             48192
# Lucknow               48192
# Chennai               48192
# Hyderabad             48107
# Patna                 44554
# Gurugram              40258
# Visakhapatnam         35053
# Amritsar              29269
# Jorapokhar            28025
# Jaipur                26705
# Thiruvananthapuram    26651
# Amaravati             22784
# Brajrajnagar          22468
# Talcher               22161
# Kolkata               19503
# Guwahati              12002
# Coimbatore             9229
# Shillong               7402
# Chandigarh             7263
# Bhopal                 6903
# Kochi                  3854
# Ernakulam              3852
# Aizawl                 2680
# Name: City, dtype: int64

# %%
stationid_1 = df3.StationId.unique()
stationid_1
# Out:
# array(['AP001', 'AP005', 'AS001', 'BR005', 'BR006', 'BR007', 'BR008',
#        'BR009', 'BR010', 'CH001', 'DL001', 'DL002', 'DL003', 'DL004',
#        'DL005', 'DL006', 'DL007', 'DL008', 'DL009', 'DL010', 'DL011',
#        'DL012', 'DL013', 'DL014', 'DL015', 'DL016', 'DL017', 'DL018',
#        'DL019', 'DL020', 'DL021', 'DL022', 'DL023', 'DL024', 'DL025',
#        'DL026', 'DL027', 'DL028', 'DL029', 'DL030', 'DL031', 'DL032',
#        'DL033', 'DL034', 'DL035', 'DL036', 'DL037', 'DL038', 'GJ001',
#        'HR011', 'HR012', 'HR013', 'HR014', 'JH001', 'KA002', 'KA003',
#        'KA004', 'KA005', 'KA006', 'KA007', 'KA008', 'KA009', 'KA010',
#        'KA011', 'KL002', 'KL004', 'KL007', 'KL008', 'MH005', 'MH006',
#        'MH007', 'MH008', 'MH009', 'MH010', 'MH011', 'MH012', 'MH013',
#        'MH014', 'ML001', 'MP001', 'MZ001', 'OD001', 'OD002', 'PB001',
#        'RJ004', 'RJ005', 'RJ006', 'TG001', 'TG002', 'TG003', 'TG004',
# ...

# %%
stationid_2 = df4.StationId.unique()
stationid_2
# Out:
# array(['AP001', 'AP005', 'AS001', 'BR005', 'BR006', 'BR007', 'BR008',
#        'BR009', 'BR010', 'CH001', 'DL001', 'DL002', 'DL003', 'DL004',
#        'DL005', 'DL006', 'DL007', 'DL008', 'DL009', 'DL010', 'DL011',
#        'DL012', 'DL013', 'DL014', 'DL015', 'DL016', 'DL017', 'DL018',
#        'DL019', 'DL020', 'DL021', 'DL022', 'DL023', 'DL024', 'DL025',
#        'DL026', 'DL027', 'DL028', 'DL029', 'DL030', 'DL031', 'DL032',
#        'DL033', 'DL034', 'DL035', 'DL036', 'DL037', 'DL038', 'GJ001',
#        'HR011', 'HR012', 'HR013', 'HR014', 'JH001', 'KA002', 'KA003',
#        'KA004', 'KA005', 'KA006', 'KA007', 'KA008', 'KA009', 'KA010',
#        'KA011', 'KL002', 'KL004', 'KL007', 'KL008', 'MH005', 'MH006',
#        'MH007', 'MH008', 'MH009', 'MH010', 'MH011', 'MH012', 'MH013',
#        'MH014', 'ML001', 'MP001', 'MZ001', 'OD001', 'OD002', 'PB001',
#        'RJ004', 'RJ005', 'RJ006', 'TG001', 'TG002', 'TG003', 'TG004',
# ...

# %%
stationid_3 = df5.StationId.unique()
stationid_3
# Out:
# array(['AP001', 'AP002', 'AP003', 'AP004', 'AP005', 'AS001', 'BR001',
#        'BR002', 'BR003', 'BR004', 'BR005', 'BR006', 'BR007', 'BR008',
#        'BR009', 'BR010', 'CH001', 'DL001', 'DL002', 'DL003', 'DL004',
#        'DL005', 'DL006', 'DL007', 'DL008', 'DL009', 'DL010', 'DL011',
#        'DL012', 'DL013', 'DL014', 'DL015', 'DL016', 'DL017', 'DL018',
#        'DL019', 'DL020', 'DL021', 'DL022', 'DL023', 'DL024', 'DL025',
#        'DL026', 'DL027', 'DL028', 'DL029', 'DL030', 'DL031', 'DL032',
#        'DL033', 'DL034', 'DL035', 'DL036', 'DL037', 'DL038', 'GJ001',
#        'GJ002', 'GJ003', 'GJ004', 'GJ005', 'GJ006', 'HR001', 'HR002',
#        'HR003', 'HR004', 'HR005', 'HR006', 'HR007', 'HR008', 'HR009',
#        'HR010', 'HR011', 'HR012', 'HR013', 'HR014', 'HR015', 'HR016',
#        'HR017', 'HR018', 'HR019', 'HR020', 'HR021', 'HR022', 'HR023',
#        'HR024', 'HR025', 'HR026', 'HR027', 'HR028', 'HR029', 'JH001',
# ...

# %%
station_by_day = df3.StationId.value_counts()
station_by_day
# Out:
# KA003    2009
# DL007    2009
# DL033    2009
# KA009    2009
# DL021    2009
#          ...
# BR005     126
# BR006     121
# HR012     119
# HR013     119
# MZ001     113
# Name: StationId, Length: 110, dtype: int64

# %%
station_by_hour = df4.StationId.value_counts()
station_by_hour
# Out:
# KA003    48192
# DL007    48192
# DL033    48192
# KA009    48192
# DL021    48192
#          ...
# BR005     2985
# BR006     2863
# HR013     2817
# HR012     2817
# MZ001     2680
# Name: StationId, Length: 110, dtype: int64

# %%
station_by_count = df5.StationId.value_counts()
station_by_count
# Out:
# AP001    1
# MH010    1
# MH012    1
# MH013    1
# MH014    1
#         ..
# HR020    1
# HR021    1
# HR022    1
# HR023    1
# WB014    1
# Name: StationId, Length: 230, dtype: int64

# %%
df.PM10
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 29526    50.94
# 29527    74.09
# 29528    65.73
# 29529    49.97
# 29530    66.00
# Name: PM10, Length: 29531, dtype: float64

# %%
df2.PM10
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 707870    36.00
# 707871    49.25
# 707872    71.00
# 707873    63.00
# 707874    66.00
# Name: PM10, Length: 707875, dtype: float64

# %%
df.AQI
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 29526    41.0
# 29527    70.0
# 29528    68.0
# 29529    54.0
# 29530    50.0
# Name: AQI, Length: 29531, dtype: float64

# %%
df.AQI[:100]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#       ...
# 95    303.0
# 96    314.0
# 97    378.0
# 98    415.0
# 99      NaN
# Name: AQI, Length: 100, dtype: float64

# %%
df2.AQI
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 707870    51.0
# 707871    51.0
# 707872    50.0
# 707873    50.0
# 707874    50.0
# Name: AQI, Length: 707875, dtype: float64

# %%
df3.AQI
# Out:
# 0           NaN
# 1         184.0
# 2         197.0
# 3         198.0
# 4         188.0
#           ...
# 108030     50.0
# 108031     65.0
# 108032     63.0
# 108033     57.0
# 108034     59.0
# Name: AQI, Length: 108035, dtype: float64

# %%
df4.AQI
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#            ...
# 2589078    59.0
# 2589079    59.0
# 2589080    59.0
# 2589081    59.0
# 2589082    59.0
# Name: AQI, Length: 2589083, dtype: float64

# %%
df.AQI_Bucket
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#              ...
# 29526            Good
# 29527    Satisfactory
# 29528    Satisfactory
# 29529    Satisfactory
# 29530            Good
# Name: AQI_Bucket, Length: 29531, dtype: object

# %%
df2.AQI_Bucket
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#               ...
# 707870    Satisfactory
# 707871    Satisfactory
# 707872            Good
# 707873            Good
# 707874            Good
# Name: AQI_Bucket, Length: 707875, dtype: object

# %%
df3.AQI_Bucket
# Out:
# 0                  NaN
# 1             Moderate
# 2             Moderate
# 3             Moderate
# 4             Moderate
#               ...
# 108030            Good
# 108031    Satisfactory
# 108032    Satisfactory
# 108033    Satisfactory
# 108034    Satisfactory
# Name: AQI_Bucket, Length: 108035, dtype: object

# %%
df4.AQI_Bucket
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#                ...
# 2589078    Satisfactory
# 2589079    Satisfactory
# 2589080    Satisfactory
# 2589081    Satisfactory
# 2589082    Satisfactory
# Name: AQI_Bucket, Length: 2589083, dtype: object

# %%
cities_by_day.plot(kind = "bar")
# Out:
# <Axes: >

# %%
cities_by_hour.plot(kind = "bar")
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate AQI
# - Since our data set has missing **AQI** values. Although we have information of all essential pollutants.Thus, we need to
#   calculate these AQI values.
# - Note for calculating **final** AQI we need data for either PM2.5 or PM10, Also data for any three Pollutants from all
#   pollutants.

# %%
# Delete rows with PM2.5 and PM10 both null.
df.dropna(axis=0, how="all", subset=['PM2.5','PM10'], inplace = True)
df.head()
# Out:
#          City        Date   PM2.5  PM10     NO    NO2    NOx  NH3     CO  \
# 27  Ahmedabad  2015-01-28   73.24   NaN   5.72  21.11  25.84  NaN   5.72
# 28  Ahmedabad  2015-01-29   83.13   NaN   6.93  28.71  33.72  NaN   6.93
# 29  Ahmedabad  2015-01-30   79.84   NaN  13.85  28.68  41.08  NaN  13.85
# 30  Ahmedabad  2015-01-31   94.52   NaN  24.39  32.66  52.61  NaN  24.39
# 31  Ahmedabad  2015-02-01  135.99   NaN  43.48  42.08  84.57  NaN  43.48
#
#       SO2      O3  Benzene  Toluene  Xylene    AQI AQI_Bucket
# 27  36.52   62.42     0.03     0.01    1.41    NaN        NaN
# 28  49.52   59.76     0.02     0.00    3.14  209.0       Poor
# 29  48.49   97.07     0.04     0.00    4.81  328.0  Very Poor
# 30  67.39  111.33     0.24     0.01    7.67  514.0     Severe
# 31  75.23  102.70     0.40     0.04   25.87  782.0     Severe

# %% [markdown]
# ## Use of AQI and Cleaned Data set
# - **MS-excel** is used to calculate sub-index, AQI, and AQI_Bucket columns.

# %%
df6 = pd.read_csv(data_filename6)
df6.head()
# Out:
#         4-03-2015   91.87  179.36   21.3  30.01  40.31  31.79   10.1   7.35  \
# Delhi  25-03-2015  107.26  201.08  21.52  33.82  42.98  27.92  11.69  11.82
# Delhi  26-03-2015  109.78  217.90  24.10  33.02  44.26  28.00  12.67   9.30
# Delhi  27-03-2015   62.27  117.81  12.01  24.76  27.71  27.34   9.29  10.91
# Delhi  28-03-2015  102.22  212.96  22.14  29.41  40.44  32.82  10.47  17.16
# Delhi  29-03-2015  104.36  202.01  23.55  33.86  43.20  37.35  14.42  16.92
#
#        34.78  ...  15.64    206   153    -400    8    70     9    35    290  \
# Delhi  45.78  ...   9.98  258.0  167.0 -396.0  7.0  74.0  15.0  46.0  340.0
# Delhi  40.00  ...   2.53  266.0  179.0 -395.0  7.0  71.0  12.0  40.0  358.0
# Delhi  31.08  ...   2.00  108.0  112.0   35.0  7.0  65.0  14.0  31.0  287.0
# Delhi  40.23  ...   2.54  241.0  175.0 -399.0  8.0  70.0  21.0  40.0  323.0
# Delhi  32.84  ...   2.51  248.0  168.0 -396.0  9.0  77.0  21.0  33.0  360.0
#
#             Poor
# Delhi  Very Poor
# ...

# %%
# Create pivot table for Understanding the type of pollution in cities.
pivot_df = df.pivot_table(index = ['AQI_Bucket'], columns = ['City'],aggfunc = 'mean')['AQI'].round(1)
pivot_df.head()
# Out:
# <ipython-input-58-3bf4edd89a16>:2: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pivot_df = df.pivot_table(index = ['AQI_Bucket'], columns = ['City'],aggfunc = 'mean')['AQI'].round(1)
# City          Ahmedabad  Aizawl  Amaravati  Amritsar  Bengaluru  Bhopal  \
# AQI_Bucket
# Good               48.0    24.5       41.6      42.7       41.4    43.0
# Moderate          154.6     NaN      137.5     132.5      128.5   133.5
# Poor              244.9     NaN      237.2     244.5      233.5   242.5
# Satisfactory       87.5    65.2       73.0      76.7       75.1    79.8
# Severe            683.8     NaN        NaN     607.0        NaN     NaN
#
# City          Brajrajnagar  Chandigarh  Chennai  Coimbatore  ...  Jorapokhar  \
# AQI_Bucket                                                   ...
# ...

# %%
pivot_df.replace(np.nan,0,inplace=True)
pivot_df
# Out:
# City          Ahmedabad  Aizawl  Amaravati  Amritsar  Bengaluru  Bhopal  \
# AQI_Bucket
# Good               48.0    24.5       41.6      42.7       41.4    43.0
# Moderate          154.6     0.0      137.5     132.5      128.5   133.5
# Poor              244.9     0.0      237.2     244.5      233.5   242.5
# Satisfactory       87.5    65.2       73.0      76.7       75.1    79.8
# Severe            683.8     0.0        0.0     607.0        0.0     0.0
# Very Poor         343.4     0.0      305.1     322.9      329.2   308.5
#
# City          Brajrajnagar  Chandigarh  Chennai  Coimbatore  ...  Jorapokhar  \
# AQI_Bucket                                                   ...
# Good                  37.9        40.1     45.9        39.8  ...        35.5
# Moderate             130.4       126.4    136.7       106.9  ...       135.7
# Poor                 250.2       244.6    229.9         0.0  ...       241.5
# ...

# %% [markdown]
# ## Status of pollution over 5 years
# - The below plot shows average pollution over five years was either
#   - Good
#   - Moderate
#   - Satisfactory
#   - Poor
#   - Very Poor
#   - Severe

# %%
plt.subplots(figsize=(15,15))
plt.xlabel('Cities', size = 15)
plt.ylabel('AQI_Bucket', size = 15)
plt.title('Level of pollution', size = 15)
sns.heatmap(pivot_df,cmap='Reds',annot=True, fmt=".1f",linewidths=.5,square = True,cbar = False);
plt.show()

# %% [markdown]
# ### Top 3 cities using bar plot

# %%
plt.subplots(figsize=(13,13))
ax = df.groupby('City')['AQI'].mean().sort_values()
ax.plot(kind='barh')
plt.title('Average AQI from 2015-2020',size=15)
plt.xlabel('Average AQI',size=15)
plt.ylabel('City',size=15)
# Out:
# Text(0, 0.5, 'City')

# %% [markdown]
# #Ask Answers Questions
# 1. Which 5 states have good Air quality? Ans 1 - Aizawl , Shilong,  Coimbatore , Thiruvanthapuram , Ernakulam
# 2.Which 5 states have bad Air quality ?Ans 2 - Ahmdabad , Delhi , Patna , Gurugram , Lucknow
# 3. what is the reason of AQI increase in some area? Ans 3 - The reason for AQI increase in the cities is due **Nitrogen Oxides**, **Particulate matter**, and **Co** pollutants.
